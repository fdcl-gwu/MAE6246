# %% [markdown]
# # MAE 6246 — Homework 3: Modal Analysis and Phase Portraits
#
# **Name:** _Enter your name._
# **Total:** 100 points
#
# ## Submission format
#
# Submit the completed IPYNB file through Blackboard. Enter analytical work in the designated Markdown response cells using LaTeX or clearly formatted algebra. If you are not familiar with LaTeX, you may instead write the analytical work on paper and submit it as a PDF file in addition to the IPYNB file. In that case, write **submitted separately as a PDF** in each corresponding response cell.
#
# Complete the eigenvalue calculations, derivations, and hand sketches before using Python for verification. Do not use SymPy or another computer-algebra system to replace the analytical work. We recommend using **graph paper** for the hand sketches. If graph paper is unavailable, draw a coordinate grid with a ruler. Include clear scans or photographs of the sketches in the accompanying PDF, or insert them into the designated notebook cell.
#
# Before submitting, restart the kernel and run all cells from top to bottom. Keep all requested figures and numerical output in the notebook. Complete all `YOUR CODE HERE` sections; function stubs raise `NotImplementedError` until you implement them.

# %% [markdown]
# ## Motivation
#
# Eigenvalues describe the time dependence of a mode, while eigenvectors determine its direction or state-space pattern. Combining modes produces the trajectories seen in a phase portrait. Complex conjugate modes provide two equivalent descriptions of the same real motion: a matrix-exponential solution and a paired complex-mode solution.
#
# This assignment asks two questions:
#
# 1. How do real eigenvalues and eigenvectors determine a phase portrait?
# 2. How do complex modes combine to produce a real state trajectory?
#
# The assignment covers the material through Section 4 of the Week 4 course note.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import expm
from scipy.integrate import solve_ivp

plt.rcParams.update({"figure.dpi": 120, "axes.grid": True})

# %% [markdown]
# ## Problem 1 — Real eigenvalues and phase portraits (50 points)
#
# Consider the three systems $\dot x=A_kx$, where
#
# $$
# A_1=\begin{bmatrix}-3&1\\2&-2\end{bmatrix},\qquad
# A_2=\begin{bmatrix}-2&2\\4&0\end{bmatrix},\qquad
# A_3=\begin{bmatrix}3&-1\\-2&2\end{bmatrix}.
# $$
#
# ### (a) Eigenvalues and eigenvectors (10 points)
#
# Find the eigenvalues and corresponding eigenvectors of each matrix. Show your analytical calculations and classify the equilibrium at the origin.
#
# Choose one of the following six types: **stable node, unstable node, stable focus (spiral), unstable focus (spiral), center, or saddle**.

# %% [markdown]
# ### Response for Problem 1(a)
#
# Replace this text with your derivation and explanation. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ### (b) Hand sketches (20 points)
#
# Sketch each phase portrait **by hand before using Python**. We recommend using **graph paper**, with one panel for each matrix. Label both axes and use the same physical length for one unit on each axis.
#
# Your sketches should include:
#
# - The origin and both eigenvector lines, with arrows indicating motion along them.
# - Representative curved trajectories between the eigenvector lines, with arrows indicating increasing time.
# - The equilibrium type in the title: **stable node, unstable node, stable focus, unstable focus, center, or saddle**.
#
# Briefly explain how the eigenvalues and eigenvectors determine each sketch. Qualitative curve shapes and correct directions matter more than exact numerical coordinates. No particular initial conditions are prescribed for the hand sketches.

# %% [markdown]
# ### Response for Problem 1(b)
#
# Insert your three hand sketches and explanations here. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ### (c) Python verification (20 points)
#
# Write Python code to generate the three phase portraits. Show the vector field, trajectories from the initial conditions below, the initial points, and the eigenvector lines. Use equal axis scales and label each plot with its matrix name and equilibrium type.
#
# **Initial conditions for the Python plots.** For each matrix, normalize the real eigenvectors found in part (a):
#
# $$
# \widehat v_j=\frac{v_j}{\|v_j\|_2},\qquad j=1,2.
# $$
#
# Use the following eight nonzero initial conditions for each matrix:
#
# $$
# \boxed{x_0\in\left\{
# \pm\rho\widehat v_1,\quad
# \pm\rho\widehat v_2,\quad
# \pm\rho(\widehat v_1+\widehat v_2),\quad
# \pm\rho(\widehat v_1-\widehat v_2)
# \right\},\qquad
# \rho=\begin{cases}
# 1.0,&A_1,\\
# 0.5,&A_2,\\
# 0.2,&A_3.
# \end{cases}}
# $$
#
# Each $\pm$ denotes two initial conditions. The first four lie on both sides of the two eigenvector lines. The remaining four lie in the four sectors between them and reveal how the modes combine. These scale factors make the trajectories visible within the common plotting window. Reversing the sign or order of the eigenvectors does not change the set. Do not use the origin as a trajectory seed: it remains fixed.
#
# Use the window $[-2,2]\times[-2,2]$ and $0\le t\le3$, with at least 1001 equally spaced time points if you evaluate the matrix exponential directly. For trajectories that leave the window, show only the visible portion or stop integration at the boundary. All trajectory arrows should indicate increasing time.
#
# You may use `quiver` or `streamplot` for the vector field and `expm` or `solve_ivp` to compute trajectories. If you use `streamplot`, also plot the trajectories from the eight prescribed initial conditions; its automatically chosen streamlines do not replace them. You may use `np.linalg.eig` to verify the eigenpairs after completing parts (a) and (b).
#
# Compare the geometric features and directions in the numerical portraits with your hand sketches and explain any corrections. The Python initial conditions do not have to match points on your hand sketches.

# %%
# Supplied matrices for Problem 1.
real_cases = {
    "A1": np.array([[-3.0, 1.0], [2.0, -2.0]]),
    "A2": np.array([[-2.0, 2.0], [4.0,  0.0]]),
    "A3": np.array([[ 3.0, -1.0], [-2.0, 2.0]]),
}

limits_p1 = (-2.0, 2.0, -2.0, 2.0)  # x1_min, x1_max, x2_min, x2_max
t_final_p1 = 3.0
rho_p1 = {"A1": 1.0, "A2": 0.5, "A3": 0.2}

# For each matrix, enter or verify your eigenvectors from part (a).
# Normalize each eigenvector to unit Euclidean length.
# Construct the eight initial states specified in part (c),
# using the corresponding scale factor from rho_p1,
# and store them as an (8, 2) array under the corresponding matrix name.
initial_states_p1 = {}  # YOUR CODE HERE

# Optional: verify your analytical eigenpairs after completing the hand work.
# YOUR CODE HERE

# %%
def draw_phase_portrait(ax, A, initial_states, t_final, limits):
    """Draw a vector field and forward-time trajectories in the state plane.

    limits = (x1_min, x1_max, x2_min, x2_max)
    """
    # 1. Build a grid and evaluate the vector field.
    # 2. Draw the vector field with arrows.
    # 3. Compute and draw trajectories from the selected initial states.
    # 4. Label x1 and x2, set the plot limits, and use equal axis scales.
    # YOUR CODE HERE
    raise NotImplementedError

# Generate the three phase portraits using the helper above or your own code.
# Use the eight prescribed initial states for each matrix.
# Overlay the real eigenvector lines, mark the initial points,
# and indicate forward-time motion. Include the equilibrium type in each title.
# YOUR CODE HERE

# %% [markdown]
# ### Response for Problem 1(c)
#
# Compare your Python phase portraits with your hand sketches. Explain any corrections. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ## Problem 2 — Complex modes and equivalent solution formulas (50 points)
#
# Consider
#
# $$
# \dot x=Ax,\qquad
# A=\begin{bmatrix}0&1\\-2&-2\end{bmatrix},\qquad
# x(0)=x_0=\begin{bmatrix}1\\0\end{bmatrix}.
# $$
#
# ### (a) Verify the eigenvalues and eigenvectors (10 points)
#
# Verify that
#
# $$
# \lambda=-1+i,\qquad
# v=\begin{bmatrix}1\\-1+i\end{bmatrix}
# $$
#
# form an eigenpair. Show the calculation $Av=\lambda v$ and identify the conjugate eigenpair.

# %% [markdown]
# ### Response for Problem 2(a)
#
# Replace this text with your derivation and explanation. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ### (b) Predict the equilibrium type (10 points)
#
# Using the eigenvalues, predict the type of equilibrium at the origin. Choose one of: **stable node, unstable node, stable focus (spiral), unstable focus (spiral), center, or saddle**.
#
# Explain your choice and state whether trajectories approach or move away from the origin. Record your prediction before computing or plotting the solution.

# %% [markdown]
# ### Response for Problem 2(b)
#
# State your prediction and explain how the eigenvalues support it. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ### (c) Solution using the matrix exponential (10 points)
#
# Compute
#
# $$
# x(t)=e^{At}x_0.
# $$
#
# Show your analytical calculation of $e^{At}$ and express both state components as real-valued functions of time.

# %% [markdown]
# ### Response for Problem 2(c)
#
# Replace this text with your derivation and explanation. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ### (d) Solution using the complex mode (10 points)
#
# Determine $c\in\mathbb C$ from
#
# $$
# x_0=cv+\overline c\,\overline v.
# $$
#
# Then compute
#
# $$
# x(t)=2\operatorname{Re}\!\left(ce^{\lambda t}v\right).
# $$
#
# Simplify the result and verify analytically that it agrees with part (c). You may also use the optional code cell below to check the two formulas numerically.

# %% [markdown]
# ### Response for Problem 2(d)
#
# Replace this text with your derivation and explanation. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %%
# Supplied data for Problem 2.
A_complex = np.array([[0.0, 1.0], [-2.0, -2.0]])
x0_complex = np.array([1.0, 0.0])
lam = -1.0 + 1.0j
v = np.array([1.0, -1.0 + 1.0j], dtype=complex)

# Optional numerical verification, after completing the analytical work:
# Enter c from part (d), evaluate both solution formulas at several times,
# and report the largest absolute difference.
# YOUR CODE HERE

# %% [markdown]
# ### (e) Python phase portrait (10 points)
#
# Write Python code to generate the phase portrait. Choose eight equally spaced initial points on the unit circle:
#
# $$
# x_0^{(k)}=\begin{bmatrix}\cos\theta_k\\\sin\theta_k\end{bmatrix},
# \qquad \theta_k=\frac{k\pi}{4},\qquad k=0,\ldots,7.
# $$
#
# These points sample all four quadrants and include the specified initial state $x_0=[1,0]^T$. Use the window $[-2,2]\times[-2,2]$ and the interval $0\le t\le6$. Plot the vector field and all eight trajectories, mark the initial points, and highlight the trajectory starting at the specified $x_0$. Include arrows showing increasing time, equal axis scales, and the equilibrium type in the title.
#
# Use the plot to check your prediction in part (b). Determine whether the motion is clockwise or counterclockwise, and confirm the direction by evaluating $Ax$ at a suitable nonzero point. Explain why that vector indicates the observed rotation direction.

# %%
# Supplied initial states and plotting settings for Problem 2(e).
theta_p2 = np.arange(8) * np.pi / 4.0
initial_states_p2 = np.column_stack((np.cos(theta_p2), np.sin(theta_p2)))
limits_p2 = (-2.0, 2.0, -2.0, 2.0)
t_final_p2 = 6.0

# Generate the phase portrait for A_complex using all eight initial states.
# You may reuse draw_phase_portrait from Problem 1(c).
# Highlight the trajectory starting at x0_complex and mark all initial points.
# Include forward-time arrows, labeled axes, equal scales, and a legend.
# Include the predicted equilibrium type in the title.
# YOUR CODE HERE

# %% [markdown]
# ### Response for Problem 2(e)
#
# Check your prediction from part (b). State the rotation direction and confirm it using the vector field at a suitable point. If you submit handwritten work as a separate PDF, write **submitted separately as a PDF** here.

# %% [markdown]
# ## Submission checklist
#
# - [ ] I found the eigenvalues and eigenvectors of all three matrices in Problem 1 analytically.
# - [ ] I included three hand-drawn phase portraits on a coordinate grid, with equal scales, eigenvector lines, representative curves, and direction arrows.
# - [ ] I used the prescribed eight initial conditions and scale factor for each Problem 1 Python portrait, and compared its geometry with my hand sketch.
# - [ ] I verified the supplied complex eigenpair and identified its conjugate.
# - [ ] I classified each equilibrium using one of the six specified types and recorded the Problem 2 prediction before plotting.
# - [ ] I derived $x(t)$ using both the matrix exponential and the complex mode and showed that they agree.
# - [ ] I generated the complex-system phase portrait from eight unit-circle initial conditions, highlighted the specified trajectory, and checked its rotation direction.
# - [ ] Every figure has a title, labeled axes, equal axis scales, and clear identification of plotted elements.
# - [ ] I restarted the kernel and ran all completed code cells from top to bottom.
# - [ ] I submitted the IPYNB file and, if applicable, the accompanying handwritten PDF through Blackboard.
